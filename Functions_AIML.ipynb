# %% [markdown]
# <a href="https://colab.research.google.com/github/srinubandaru/AIML/blob/main/Functions_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Definition of the function
#Name of the function
def MyMsgs_Shows():   #Indentation of the function (right)
    #Body of the function
    #Logical part of the function
    #Called part of the function
    #Argument declaration section
    print("Hey Welcome to Functions")
    print('Good One')
    #End of the function
    #Always Optional
    #It is the statement
    return()

#Calling Part
#Passing Parameters
#Passed values are parameters
#Code recalling/Reusable
MyMsgs_Shows()
MyMsgs_Shows()
# Out:
# Hey Welcome to Functions
# Good One
# Hey Welcome to Functions
# Good One
# ()

# %%
#Example:
def MyMsgs_Shows():
    print("Hey Welcome to Functions")
    print('Good One')
    return()

MyMsgs_Shows()
# Out:
# Hey Welcome to Functions
# Good One
# ()

# %%
def Sum(arg1, arg2):
    total = arg1 + arg2
    print("The Total is:", total)
    return;
total = Sum(30,20);
# Out:
# The Total is: 50

# %%
def Tot_Sub(a, b):
    Tot = a + b
    Sub = a - b
    return (Tot, Sub)

x, y = Tot_Sub(10, 20)
print("The Sum is :", x)
print("The Subtraction is :", y)
# Out:
# The Sum is : 30
# The Subtraction is : -10

# %%
def printMy(str):
  print(str)
  return
printMy("Hello")
# Out:
# Hello

# %%
def fun(a, b, c):
    print(a, b, c)

fun(c=3, b=2, a=1)

# %%
def printMy(str):
    print(str)
    return;

printMy(str="RoboticProcessAutomation-RPA")

# %%
def nsquare(x, y = 2):
    return (x*x + y*y)

print("The square of the sum of 2 and 2 is : ", nsquare(2))
print("The square of the sum of 2 and 4 is : ", nsquare(2,4))
# Out:
# The square of the sum of 2 and 2 is :  8
# The square of the sum of 2 and 4 is :  20

# %%
def printinfo(name, exp = '15+'):
    print("Name:", name)
    print("Experience:", exp)
    return;

printinfo(exp=14, name="KSRaju")
printinfo(name="GenAI")
# Out:
# Name: KSRaju
# Experience: 14
# Name: GenAI
# Experience: 15+

# %%
def Scores(BigData, Hadoop=85, Spark=80):
    print(BigData, Hadoop, Spark)

Scores(71, 77)
Scores(65, Spark=74)
Scores(BigData=70, Hadoop=90, Spark=75)
# Out:
# 71 77 80
# 65 85 74
# 70 90 75

# %%
def fun(*arr):
    for val in arr:
        print(val)

fun()
fun(10)
fun(10, 20)
fun(10, 20, 30)
# Out:
# 10
# 10
# 20
# 10
# 20
# 30

# %%
x=600
print(id(x))
# Out:
# 132138718626960

# %%
x = 100

def MyFun():
    global x
    x = 5
    y = 20
    print(x + y)

def MyFun1():
    y = 10
    print(x + y)

MyFun()
MyFun1()
# Out:
# 25
# 15

# %%
x = 1

def Compute():
    global x
    for i in (1, 2, 3):
        x += 1

Compute()
print(x)
# Out:
# 4

# %%
def Hello_world(name):
    print("Great:", name)

MyWorld = Hello_world

Hello_world('Machine Learning')
MyWorld("PYTHON")

print(id(MyWorld))
print(id(Hello_world))
# Out:
# Great: Machine Learning
# Great: PYTHON
# 138613328569152
# 138613328569152

# %%
def Outer():   # outer function
    print("Hello Welcome TO")

    def Inner():   # inner function
        print("Nested Functions")

    Inner()

Outer()
# Out:
# Hello Welcome TO
# Nested Functions

# %%
def Outer_Fun():
    print("Say Hey Outer Function")

def Inner_Fun():
    print("Bye Hey Inner Function")

print("OuterOneCallingInnerFunction")

Inner_Fun()
Outer_Fun()
# Out:
# OuterOneCallingInnerFunction
# Bye Hey Inner Function
# Say Hey Outer Function

# %%
def Outer_Fun():
    print("Hey Outer")

    def inner():
        print("Bye Inner")

    print("Outer Returns Inner")
    return inner

Outer_Fun()
# Out:
# Hey Outer
# Outer Returns Inner
# <function __main__.Outer_Fun.<locals>.inner()>

# %%
def Outer_Fun():
    print("Hey Outer")

    def inner():
        print("Bye Inner")

    print("Outer Returns Inner")
    return inner()

Outer_Fun()
# Out:
# Hey Outer
# Outer Returns Inner
# Bye Inner

# %%
def Outer():
    x = 1

    def Inner(a):
        print(a + x)

    Inner(2)

Outer()
# Out:
# 3

# %%
def Outer():  # outer function
    x = 1  # variable defined in the outer function

    def Inner(a):  # inner function
        # will create a new variable in the inner function
        # instead of changing the value of x of outer function
        x = 4
        print(a + x)

    print(x)  # prints the value of x of outer function
    Inner(2)

Outer()
# Out:
# 1
# 6

# %%
def Outer_Function():
    a = 5
    def Inner_Function():
        nonlocal a
        a = 10
        print("Inner Function:", a)
    Inner_Function()
    print("Outer Function:", a)

Outer_Function()
# Out:
# Inner Function: 10
# Outer Function: 10

# %%
def Outer_Function():
    a = 5
    def Inner_Function():
        a = 10
        print("Inner Function:", a)
    Inner_Function()
    print("Outer Function:", a)

Outer_Function()
# Out:
# Inner Function: 10
# Outer Function: 5

# %%
def factorial(n):
    if n == 1:
        return 1
    else:
        return n * factorial(n-1)

print(factorial(5))
# Out:
# 120

# %%
def counter(c):
    if c <= 0:
        return c
    else:
        return c + counter(c-1)

print(counter(5))
# Out:
# 15

# %%
print((lambda x, y: x + y)(2, 3))
# Out:
# 5

# %%
def average(x, y):
    return (x + y) / 2

print(average(4, 3))
# Out:
# 3.5

# %%
print((lambda x, y: (x + y) / 2)(4, 3))
# Out:
# 3.5

# %%
def max(x, y):
    if x > y:
        return x
    else:
        return y

print(max(15, 6))
# Out:
# 15

# %%
max = lambda x, y: x if x > y else y
print(max(15, 6))
# Out:
# 15

# %%
print((lambda x, y: x if x > y else y)(2, 3))
# Out:
# 3

# %%
max = lambda x, y: x if x < y else y
print(max(5, 6))
# Out:
# 5

# %% [markdown]
# map() function
# Apply same function to each element of a sequence and return the modified list.
#
# Syntax:
# list = [m, n, p]
# function(), f  ==> MAP ==> New list, [f(m), f(n), f(p)]

# %%
list(map(lambda x: x**2, [4, 3, 2, 1]))
# Out:
# [16, 9, 4, 1]

# %%
my_list = [1, 5, 4, 6, 8]
new_list = list(map(lambda x: x * 2, my_list))
print(new_list)
# Out:
# [2, 10, 8, 12, 16]

# %%
num = [1.1, 2.3, 4.5]
Result = list(map(lambda x: int(x), num))
print(Result)
# Out:
# [1, 2, 4]

# %%
#Example: Without Lambda:
PyTuple = (1,2,3,4,5)

def Compute(x):
    return x**2

PyTuple1 = tuple(map(Compute, PyTuple))
print(PyTuple1)
# Out:
# (1, 4, 9, 16, 25)

# %% [markdown]
# filter() function: filter items out of a sequence, return filtered list
#
# Syntax:
# list, [m, n, p]
# condition, c() ==> filter ==> New list [m, n]
#     if (m == condition)

# %%
list(filter(lambda x: x > 2, [4,3,2,1]))
# Out:
# [4, 3]

# %%
my_list = [1, 2, 3, 5, 6, 8, 10, 12, 15]

Even_list = list(filter(lambda x: (x % 2 == 0), my_list))
print(Even_list)
# Out:
# [2, 6, 8, 10, 12]

# %%
Odd_list = list(filter(lambda x: (x % 2 != 0), my_list))
print(Odd_list)
# Out:
# [1, 3, 5, 15]

# %% [markdown]
# reduce() function:
# 1. Applies same operation to items of a sequence
# 2. Uses result of operation as first param of next operation
# 3. Returns an item, not a list. This function is defined in functools module.
#
# Syntax:
# list, [m, n, p]
# function f() ==> reduce() ==> f(f(m,n),p)

# %%
import functools
n = [4,3,2,1]
print(functools.reduce(lambda x, y: x * y, n))
# Out:
# 24

# %%
import functools
print(functools.reduce(lambda x, y: x + y, [1,2,3,4]))
result = sum([x for x in [1,2,3,4]])
print(result)
# Out:
# 10
# 10

# %%
def Add(*num):
    Sum = 0
    for n in num:
        Sum = Sum + n
    print("Sum is:", Sum)

Add(3, 5)
Add(4, 5, 6, 7)
Add(1, 2, 3, 5, 6)
# Out:
# Sum is: 8
# Sum is: 22
# Sum is: 17

# %%
def print_kwargs(**kwargs):
    print(kwargs)

print_kwargs(kwargs1="KORA", kwargs2="Subba Raju")
print_kwargs(kwargs1="KORA", kwargs2="Subba Raju", kwargs3="20-Years")
# Out:
# {'kwargs1': 'KORA', 'kwargs2': 'Subba Raju'}
# {'kwargs1': 'KORA', 'kwargs2': 'Subba Raju', 'kwargs3': '20-Years'}

# %%
def print_values(**kwargs):
    for key, value in kwargs.items():
        print(key, value)
print_values(kwargs="KORA", kwargs2="Subba Raju", kwargs3="20-Years")
# Out:
# kwargs KORA
# kwargs2 Subba Raju
# kwargs3 20-Years

# %%
def print_values(**kwargs):
    for key, value in kwargs.items():
        print("The value of {} is {}".format(key, value))

print_values(MyName="Raju", YourName="Ravi")
# Out:
# The value of MyName is Raju
# The value of YourName is Ravi

# %%
def print_values(**kwargs):
    for key, value in kwargs.items():
        print("The value of {} is {}".format(key, value))

print_values(
    Name1="Alex",
    Name2="Gray",
    Name3="Harper",
    Name4="Raju",
    Name5="SARA",
    Name6="SCOTT"
)
# Out:
# The value of Name1 is Alex
# The value of Name2 is Gray
# The value of Name3 is Harper
# The value of Name4 is Raju
# The value of Name5 is SARA
# The value of Name6 is SCOTT

# %%
a = input("Enter any Number")
b = input("Enter any Number")
c = a / b
print("The Value is:", c)
# Out:
# Enter any Number4
# Enter any Number2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1695/1019241350.py in <cell line: 0>()
#       1 a = input("Enter any Number")
#       2 b = input("Enter any Number")
# ----> 3 c = a / b
#       4 print("The Value is:", c)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
number = int(input("Enter Any Number: "))
print("You Are Entered:", number)
# Out:
# Enter Any Number: uhg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1695/1750284497.py in <cell line: 0>()
# ----> 1 number = int(input("Enter Any Number: "))
#       2 print("You Are Entered:", number)
#
# ValueError: invalid literal for int() with base 10: 'uhg'

# %%
try:
    x = int(input("Enter a value: "))
    print("Try Block: Enter Number is:", x)

except ValueError:
    print("Except Block: Invalid Input Enter Only Numbers")
# Out:
# Enter a value: gyyu
# Except Block: Invalid Input Enter Only Numbers

# %%
try:
    a = int(input("Enter any Number: "))
    b = int(input("Enter any Number: "))
    c = a / b
    print("The Value is:", c)

except Exception as arg:
    print("Error Occured:", arg)
# Out:
# Enter any Number: uhuh
# Error Occured: invalid literal for int() with base 10: 'uhuh'

# %%
try:
    p = int(input("Enter Any Number: "))
    q = int(input("Enter Any Number: "))
    r = p / q
    print("The Value is:", int(r))
    print("TryBlockIsExecuted")

except ValueError:
    print("ExceptBlock")
    print("Sorry User Numbers Only Valid")

except Exception as arg:
    print("You can't divide by zero.")
    print("Error:", arg)
# Out:
# Enter Any Number: 12
# Enter Any Number: 0
# You can't divide by zero.
# Error: division by zero

# %%
try:
    x = int(input("Enter Any Input: "))
    y = int(input("Enter Any Input: "))
    z = x / y
    print(z)

except ValueError:
    print("SorryAlphabetsUnableToCompute")
    print("Special Chars Also Not Accepted")

except Exception as arg:
    print("Error:", arg)

else:
    print("Welcome to Else Block")
    print("Else Block Successfully Executed")
    print("Welcome to More Computations")
    print(x + y)
    print(x - y)
    print(x * y)
# Out:
# Enter Any Input: 12
# Enter Any Input: 2
# 6.0
# Welcome to Else Block
# Else Block Successfully Executed
# Welcome to More Computations
# 14
# 10
# 24

# %%
try:
    x = int(input("Enter Any Input: "))
    y = int(input("Enter Any Input: "))

    z = x / y
    print(z)

    print("Welcome to More Computations")
    print(x + y)
    print(x - y)
    print(x * y)

except ValueError:
    print("SorryAlphabetsUnableToCompute")
    print("Special Chars Also Not Accepted")

except Exception as arg:
    print("Error:", arg)

else:
    print("Welcome to Else Block")
    print("Else Block Successfully Executed")
# Out:
# Enter Any Input: 12
# Enter Any Input: 3
# 4.0
# Welcome to More Computations
# 15
# 9
# 36
# Welcome to Else Block
# Else Block Successfully Executed

# %%
try:
    x = int(input("Enter Required Number: "))
    y = int(input("Enter Required Number: "))
    print("The Result is:", int(x / y))

except:
    print("Arithmetic Exception Raised.")

else:
    print("SuccessfullyDone")
# Out:
# Enter Required Number: hu
# Arithmetic Exception Raised.

# %%
try:
    print("OuterTryBlock")

    try:
        print("InnerTryBlock")

    except ZeroDivisionError:
        print("InnerExceptBlock")

    finally:
        print("InnerFinallyBlock")

except:
    print("OuterExceptBlock")

finally:
    print("OuterFinallyBlock")
# Out:
# OuterTryBlock
# InnerTryBlock
# InnerFinallyBlock
# OuterFinallyBlock

# %%
class Car():
  """This is DocString"""
  pass
print(Car)
print(type(Car))
print(Car.__name__)
print(Car.__doc__)
# Out:
# <class '__main__.Car'>
# <class 'type'>
# Car
# This is DocString

# %%
class Car():
    """This is docstring, explains brief about the class"""
    pass

CC = Car()
print(type(CC))
print(CC)
print(isinstance(CC, Car))
print(type(Car))
# Out:
# <class '__main__.Car'>
# <__main__.Car object at 0x7c84c0b7cf80>
# True
# <class 'type'>

# %%
class MyBank_SBI():
    pass

class MyBank_AB:
    pass

class MyBank_HDFC(object):
    pass

# SS is an Object or Instance
SS = MyBank_SBI()
print(SS)

# AA is an Object or Instance
AA = MyBank_AB()
print(AA)

# HH is an Object or Instance
HH = MyBank_HDFC()
print(HH)
# Out:
# <__main__.MyBank_SBI object at 0x7c84c0b7d640>
# <__main__.MyBank_AB object at 0x7c84c0b3bbf0>
# <__main__.MyBank_HDFC object at 0x7c84c0b3aa20>

# %%
class Banking():
    # Class Body or Logic
    print("Welcome to Banking")

# Creating Instance or Object
# Driver Code
BB = Banking()
print(BB)  # display the address of Object or Instance
# Out:
# Welcome to Banking
# <__main__.Banking object at 0x7c84c0b7cef0>

# %%
class Banking():
# It is a Method of Member
# Class inside all are members
    def MyCustomer():
        print("Welcome to Banking")
        return()

# Driver Code
BB = Banking()
BB.MyCustomer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_262/3005344319.py in <cell line: 0>()
#       8 # Driver Code
#       9 BB = Banking()
# ---> 10 BB.MyCustomer()
#
# TypeError: Banking.MyCustomer() takes 0 positional arguments but 1 was given

# %%
class Banking():
# It is a Method of Member
# Class inside all are members
    def MyCustomer(self):
        print("Welcome to Banking")
        return()

# Driver Code
BB = Banking()
BB.MyCustomer()
# Out:
# Welcome to Banking
# ()

# %%
class Banking():
# It is a Method of Member
# Class inside all are members
    def MyCustomer(self):
        print("Welcome to Banking")
        return

# Driver Code
BB = Banking()
BB.MyCustomer()
# Out:
# Welcome to Banking

# %%
class Banking():
# It is a Method of Member
# Class inside all are members
    def MyCustomer(self):
        print("Welcome to Banking")
        print(id(self))

# Driver Code
BB = Banking()
BB.MyCustomer()
print(id(BB))
# Out:
# Welcome to Banking
# 136909239522496
# 136909239522496

# %%
class Banking():
    def MyCustomer(x):
        print("Welcome to Banking")
        return(id(x))

# Driver Code
BB = Banking()
BB.MyCustomer()
# Out:
# Welcome to Banking
# 136909239421120

# %%
class Banking():
    def __init__(self):
        print("Welcome to Special Method...!!")
        print("It is get executed, when created Object")
        print("TQ")

# %%
class Banking():
    # Constructor
    def __init__(self):
        print("Welcome to Special Method...!!")
        print("It is get executed, when created Object")
        print("TQ")

    # Instance Method...!!
    def Bye(self):
        print("Bye Bye...!!")

BB = Banking()
BB.Bye()
# Out:
# Welcome to Special Method...!!
# It is get executed, when created Object
# TQ
# Bye Bye...!!

# %%
def __init__(self):
    print("Hello I am Always First Get Executed")
    print("Thank U")

# Creating an Object
MM = MyBanking()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7681/4156174312.py in <cell line: 0>()
#       4
#       5 # Creating an Object
# ----> 6 MM = MyBanking()
#
# NameError: name 'MyBanking' is not defined

# %%
class MyBanking():
    def __init__(self, name):
        print("Hello I am Always First Get Executed")
        print("Thank U")

        # Instance Variable is name
        self.name = name
        print("My Name is:", self.name)

# Creating Object or Instance / Driver Code
MM = MyBanking("PYTHON")
# Out:
# Hello I am Always First Get Executed
# Thank U
# My Name is: PYTHON

# %%
class MyBanking():
    def __init__(self, a):
# Out:
#   File "/tmp/ipykernel_7681/2472828590.py", line 2
#     def __init__(self, a):
#                           ^
# SyntaxError: incomplete input

# %%
class person():
    def __init__(self, name):
        self.name = name

    def display(self):
        print("Hello", self.name)
        return

MyObj = person('Raju')
MyObj.display()
# Out:
# Hello Raju

# %%
class Test():
    def __init__(self):
        print("Hei I am a Constructor..")

    def Method(self):
        print("Hello I am a Method..")

Tst_One = Test()
Tst_Two = Test()
Tst_Three = Test()

Tst_One.Method()
# Out:
# Hei I am a Constructor..
# Hei I am a Constructor..
# Hei I am a Constructor..
# Hello I am a Method..

# %%
class Emp():
    def __init__(self):
        self.eid = 1
        self.ename = 'Rama'
        self.esal = "$1000"

eDetails = Emp()
print(eDetails.__dict__)
# Out:
# {'eid': 1, 'ename': 'Rama', 'esal': '$1000'}

# %%
class MyClass():
    def __init__(self):
        self.x = 100

    def MyMethod(self):
        self.x = 200
        self.y = 300

MM = MyClass()
MM.MyMethod()
MM.y = 400
MM.z = 500
print(MM.__dict__)
# Out:
# {'x': 200, 'y': 400, 'z': 500}

# %%
class MyClass():
    def __init__(self):
        self.x = 100

    def MyMethod(self):
        self.x = 200
        self.y = 300

        # Deleting Instance variables
        del self.x

MM = MyClass()
MM.MyMethod()
MM.y = 400

# Deleting Instance variables
del MM.y

MM.z = 500
print(MM.__dict__)
# Out:
# {'z': 500}

# %%
class MyClass():
    def __init__(self):
        self.x = 100
        self.y = 200

MM1 = MyClass()
MM1.x = 300

MM2 = MyClass()
MM2.y = 400

print(MM1.x, MM1.y)
# Out:
# 300 200

# %%
class MyClass():
    def __init__(self):
        self.x = 100
        self.y = 200

MM1 = MyClass()
MM1.x = 300

MM2 = MyClass()
MM2.y = 400

print(MM1.x, MM1.y)
print(MM2.x, MM2.y)
# Out:
# 300 200
# 100 400

# %%
class MyClass():
    # Static Variable
    x = 1

    def __init__(self):
        self.y = 2

MM1 = MyClass()
MM1.y = 333

MyClass.x = 666

MM2 = MyClass()

print(MM1.x, MM1.y)
print(MM2.x, MM2.y)
# Out:
# 666 333
# 666 2

# %%
class MyClass():
    x = 1

    def __init__(self):
        self.y = 2

MM1 = MyClass()
MM1.y = 333
MM1.x = 666

MM2 = MyClass()

print(MM1.x, MM1.y)
print(MM2.x, MM2.y)
# Out:
# 666 333
# 1 2

# %%
class MyClass():
    # We can declare within the class directly
    p = 1

    def __init__(self):
        # Inside constructor by using class name
        MyClass.q = 2

    def MyMethod(self):
        # Inside instance method by using class name
        MyClass.r = 3

    @classmethod
    def ClassMethod(cls):
        # Inside classmethod by using either class name or cls variable
        MyClass.s = 4
        cls.t = 5

    @staticmethod
    def StaticMethod():
        # Inside static method by using class name
        MyClass.u = 5

print(MyClass.__dict__)
# Out:
# {'__module__': '__main__', 'p': 1, '__init__': <function MyClass.__init__ at 0x78b1953d6200>, 'MyMethod': <function MyClass.MyMethod at 0x78b1953d6020>, 'ClassMethod': <classmethod(<function MyClass.ClassMethod at 0x78b1953d5ee0>)>, 'StaticMethod': <staticmethod(<function MyClass.StaticMethod at 0x78b1953d5e40>)>, '__dict__': <attribute '__dict__' of 'MyClass' objects>, '__weakref__': <attribute '__weakref__' of 'MyClass' objects>, '__doc__': None}

# %%
class MyClass():
    # We can declare within the class directly
    p = 1

    def __init__(self):
        # Inside constructor by using class name
        MyClass.q = 2

    def MyMethod(self):
        # Inside instance method by using class name
        MyClass.r = 3

    @classmethod
    def ClassMethod(cls):
        # Inside classmethod by using either class name or cls variable
        MyClass.s = 4
        cls.t = 5

    @staticmethod
    def StaticMethod():
        # Inside static method by using class name
        MyClass.u = 5

print(MyClass.__dict__)
# Out:
# {'__module__': '__main__', 'p': 1, '__init__': <function MyClass.__init__ at 0x7a156a9c3100>, 'MyMethod': <function MyClass.MyMethod at 0x7a156a9c31a0>, 'ClassMethod': <classmethod(<function MyClass.ClassMethod at 0x7a156a9c3240>)>, 'StaticMethod': <staticmethod(<function MyClass.StaticMethod at 0x7a156a9c32e0>)>, '__dict__': <attribute '__dict__' of 'MyClass' objects>, '__weakref__': <attribute '__weakref__' of 'MyClass' objects>, '__doc__': None}

# %%
class Pet:
    def eat(self):
        print("Eating...")

class dog(Pet):
    def bark(self):
        print("barking")

d = dog()

d.eat()
d.bark()

# %%
class Pet:
    def eat(self):
        print('Eating...')

class Dog(Pet):
    def bark(self):
        print("barking")

class Puppy(Dog):
    def Moon(self):
        print("Puppy Crying...!!")

PP = Puppy()

PP.eat()
PP.bark()
PP.Moon()
# Out:
# Eating...
# barking
# Puppy Crying...!!

# %%
class GrandFather():
    def Hello_GFather(self):
        print("I am in GrandFather Class")

class Father(GrandFather):
    def Hello_Father(self):
        print("I am in Father Class")

class Child(Father):
    def Hello_Child(self):
        print("I am in Child Class")

ch = Child()

ch.Hello_GFather()
ch.Hello_Father()
ch.Hello_Child()
# Out:
# I am in GrandFather Class
# I am in Father Class
# I am in Child Class

# %%
class First():
    def A(self):
        print("I am in First PClass")

class Second():
    def B(self):
        print("I am in Second PClass")

class Third(First, Second):
    def C(self):
        print("I am in Child Class")

TT = Third()

TT.A()
TT.B()
TT.C()
# Out:
# I am in First PClass
# I am in Second PClass
# I am in Child Class

# %%
class First():
    def __init__(self):
        print("init of First Class")

    def A(self):
        print("I am in First PClass")


class Second():
    def __init__(self):
        print("init of Second Class")

    def B(self):
        print("I am in Second PClass")


class Third(First, Second):
    def __init__(self):
        super().__init__()
        print("init of Third Class")

    def C(self):
        print("I am in Child Class")


TT = Third()

print(Third.mro())

# %%
class A:
    def process(self):
        print('A process()')

class B:
    pass

class C(A, B):
    pass

obj = C()
obj.process()

print(C.mro())
# Out:
# A process()
# [<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>]

# %%
class Hello():
    def MyOne(self):
        print("I am in Hello Class")

class Hei(Hello):
    def MyTwo(self):
        print("I am in Hei Class")

class Bye(Hello):
    def MyThree(self):
        print("I am, in Bye Class")

HH = Hei()
HH.MyOne()
HH.MyTwo()

BB = Bye()
BB.MyOne()
BB.MyThree()
# Out:
# I am in Hello Class
# I am in Hei Class
# I am in Hello Class
# I am, in Bye Class

# %%
class A:
    def m(self):
        print("method from Class A....")


class B(A):
    def m(self):
        print("method from Class B....")


class C(A):
    def m(self):
        print("method from Class C....")


class D(B, C):
    def m(self):
        print("method from Class D....")

        B.m(self)
        C.m(self)
        A.m(self)


def main():
    obj1 = D()
    obj1.m()


if __name__ == "__main__":
    main()
# Out:
# method from Class D....
# method from Class B....
# method from Class C....
# method from Class A....
